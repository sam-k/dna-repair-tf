# %%
import subprocess
subprocess.call(["./clean_data.sh"])
# Out:
# 0

# %%
import numpy as np
import collections

pos_dict = collections.defaultdict(int)
with open("./data/ssm.open.SKCM-US_centered.bed") as f:
    for line in f:
        _,_,pos = line.strip().split()
        pos_dict[pos] += 1
mut_positions = np.array(list(pos_dict.items()), dtype=int)

# %%
from matplotlib import pyplot as plt

X = sorted([int(key) for key in pos_dict.keys()])
y = [pos_dict[str(key)] for key in X]

plt.plot(X, y)
plt.xlim(min(X), max(X))
plt.xlabel("")
plt.show()
